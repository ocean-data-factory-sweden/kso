# %% [markdown]
# ## Data Preparation

# %%
from kso import (
    ProjectManager,
    run_augmentation,
)
# Out:
# 16-Jun-26 13:26:32 - INFO - Using default logging config without output log file

# %% [markdown]
# ## BIIGLE conversion

# %%
proj = ProjectManager()
proj.preprocess_Biigle(
    data_path="~/desktop/output/biigle_dataset/27737-baltic.csv",
    images_root="~/desktop/output/biigle_dataset/baltic_images",
)

# %% [markdown]
# #### OPTIONAL DATA AUGMENTATION

# %%
# Controls whether and how dataset augmentation is applied.
# - AUGMENT_FACTOR: fraction of the dataset to augment (0–1)
# - RANDOM_SEED: ensures reproducibility
augment_factor = 0.5
random_seed = 42

run_augmentation(
    data_yaml_path="kso/projects/data/test_yolo.yaml",
    augment_factor=augment_factor,
    random_seed=random_seed,
)
# Out:
# 2026-06-16 13:26:36,393 - INFO - ✓ Augmentation complete
# 2026-06-16 13:26:36,394 - INFO -   Created 2 new images
# 2026-06-16 13:26:36,394 - INFO -   Train set: 4 → 6 images
# Using train images: /Users/ghaith/Desktop/kso/projects/data/images/train
# Using train labels: /Users/ghaith/Desktop/kso/projects/data/labels/train
