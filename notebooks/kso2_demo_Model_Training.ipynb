# %% [markdown]
# # Model training notebook

# %% [markdown]
# # Import necessary libraries and functions from the kso2 package

# %%
# These functions handle project creation, data management, model training, and serving.
import os
from kso2 import (
    load_project,
    add_model,
    training_model,
    start_mlflow_server,
    stop_mlflow_server,
    export_experiment,
    import_experiment,
)
# Out:
# 08-Feb-26 00:46:24 - INFO - Using default logging config without output log file
# /Users/ghaith/Desktop/kso/kso/.venv/lib/python3.12/site-packages/mlflow/pyfunc/utils/data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(

# %% [markdown]
# ## Create a new project instance.

# %%
# This initializes the project structure, creating necessary folders and configuration files.
project = load_project(
    Project_path="~/desktop/test_project_1/test_project_1.project.yaml"
)
# Out:
# 08-Feb-26 00:46:26 - INFO - data was retreived successfully
# 08-Feb-26 00:46:26 - INFO - ~/desktop/test_project_1/test_project_1.project.yaml loaded successfully
# {'Project_name': 'test_project_1',
#  'Project_path': '/Users/ghaith/desktop/test_project_1',
#  'Config_file_path': '/Users/ghaith/desktop/test_project_1/test_project_1.project.yaml',
#  'data_path': {'ultralytics_data_path': None,
#                'Biigle_path': '/Users/ghaith/desktop/test_project_1/data.yaml'},
#  'models': [{'model_path': 'yolov8n.pt', 'model_name': 'best model'}],
#  'tracking': {'Mlflow': {'path': None,
#                          'experiment_name': None,
#                          'mlflow.db': '/Users/ghaith/desktop/test_project_1/mlflow.db'}},
#  'metadata': None}

# %% [markdown]
# ## Configure the model to be used for training.

# %%
# 'yolov8n.pt' is a nano version of YOLOv8, which is small and fast, making it good for quick tests.
# You can specify other YOLO versions or provide a path to a local model file.
# See available models here: https://docs.ultralytics.com/models/
add_model(project=project, model_path="yolov8n.pt", model_name="test model")
# Out:
# 08-Feb-26 00:46:29 - INFO - data was retreived successfully
# 08-Feb-26 00:46:29 - INFO - data was dumped successfully
# 08-Feb-26 00:46:29 - INFO - Project YAML model name updated at /Users/ghaith/desktop/test_project_1/test_project_1.project.yaml
# {'Project_name': 'test_project_1',
#  'Project_path': '/Users/ghaith/desktop/test_project_1',
#  'Config_file_path': '/Users/ghaith/desktop/test_project_1/test_project_1.project.yaml',
#  'data_path': {'ultralytics_data_path': None,
#                'Biigle_path': '/Users/ghaith/desktop/test_project_1/data.yaml'},
#  'models': [{'model_path': 'yolov8n.pt', 'model_name': 'best model'},
#             {'model_name': 'test model',
#              'model_path': '/Users/ghaith/desktop/test_project_1/yolov8n.pt'}],
#  'tracking': {'Mlflow': {'path': None,
#                          'experiment_name': None,
#                          'mlflow.db': '/Users/ghaith/desktop/test_project_1/mlflow.db'}},
#  'metadata': None}

# %% [markdown]
# ## Start the training process.

# %%
# 'epochs' determines the number of training passes over the dataset.
# We use 1 epoch here for a quick demonstration. For real training, you would typically use 50-100+ epochs.
training_model(project=project, epochs=1)
# Out:
# mlflowdb_path:/Users/ghaith/desktop/test_project_1/mlflow.db
# 08-Feb-26 00:46:53 - INFO - data was retreived successfully
# 2026/02/08 00:46:53 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/02/08 00:46:53 INFO mlflow.store.db.utils: Updating database tables
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2026/02/08 00:46:53 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# ...

# %% [markdown]
# ## Start the MLflow server to track experiments and visualize results.

# %%
# The server runs in the background and logs output to 'mlflow.log'.
# You can access the MLflow UI in your browser (usually at http://127.0.0.1:8080).
start_mlflow_server(project=project)
# Out:
# 08-Feb-26 00:48:44 - INFO - MLflow server, address 127.0.0.1:8080...
# 08-Feb-26 00:48:46 - INFO - The MLflow server is running. Please visit: http://127.0.0.1:8080
# 08-Feb-26 00:48:46 - INFO - The browser has opened automatically.
#
# execute stop_mlflow_server function to stop the MLflow server...
# True

# %% [markdown]
# ## Stop the MLflow server.

# %%
# Use this to shut down the background process when you are finished with the notebook.
stop_mlflow_server()
# Out:
# 08-Feb-26 00:51:51 - INFO - Looking for port 8080 MLflow service on...
# 08-Feb-26 00:51:51 - INFO - turn up 6 MLflow related processes:
# 08-Feb-26 00:51:51 - INFO -   PID: 4410, Order: /Users/ghaith/Desktop/kso/kso/.venv/bin/python3 -m uvicorn --host 127.0.0.1 --port 8080 --workers 4 ...
# 08-Feb-26 00:51:51 - INFO -   PID: 4412, Order: /Users/ghaith/Desktop/kso/kso/.venv/bin/python3 -c from multiprocessing.spawn import spawn_main; spa...
# 08-Feb-26 00:51:51 - INFO -   PID: 4413, Order: /Users/ghaith/Desktop/kso/kso/.venv/bin/python3 -c from multiprocessing.spawn import spawn_main; spa...
# 08-Feb-26 00:51:51 - INFO -   PID: 4414, Order: /Users/ghaith/Desktop/kso/kso/.venv/bin/python3 -c from multiprocessing.spawn import spawn_main; spa...
# 08-Feb-26 00:51:51 - INFO -   PID: 4415, Order: /Users/ghaith/Desktop/kso/kso/.venv/bin/python3 -c from multiprocessing.spawn import spawn_main; spa...
# ...

# %% [markdown]
# ## Export the experiment artifacts.

# %%
# This saves the trained model, configuration, and metadata.
# The exported model can be reused later or deployed to a production environment.
# NOTE: The MLflow server needs to be running before exporting.
export_experiment(project)

# %% [markdown]
# ## Import the experiment artifacts.

# %%
# Imports a previously exported MLflow experiment into the current MLflow tracking server.
# This restores runs, metrics, parameters, artifacts, and experiment structure from the export directory.
import_experiment(
    project, input_dir="/Users/ghaith/Desktop/kso/kso/projects/test_project_1/output"
)
