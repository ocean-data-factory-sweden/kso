# %% [markdown]
# # Project setup

# %% [markdown]
# ## Install dependencies and the kso2 package from the parent directory.

# %%
# Note: We recommend using 'uv' for faster dependency resolution, but 'pip' is fully supported.
# Uncomment the following line to install if running for the first time:
# %uv sync
# or
# %pip install -e ..

# %% [markdown]
# # Import necessary libraries and functions from the kso2 package

# %%
# These functions handle project creation, data management, model training, and serving.
import os
from kso2 import (
    create_project,
    add_data,
    run_augmentation,
)
# Out:
# 08-Feb-26 00:46:09 - INFO - Using default logging config without output log file
# /Users/ghaith/Desktop/kso/kso/.venv/lib/python3.12/site-packages/mlflow/pyfunc/utils/data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(

# %% [markdown]
# ## Create a new project instance.

# %%
# This initializes the project structure, creating necessary folders and configuration files.
project = create_project(
    Project_name="Test project 1",
    Project_path="~/desktop",
    model_name="best model",
    weights_path="yolov8n.pt",
)
# Out:
# 08-Feb-26 00:46:11 - INFO - data was dumped successfully
# 08-Feb-26 00:46:11 - INFO - Project YAML created at /Users/ghaith/desktop
# {'Project_name': 'test_project_1',
#  'Project_path': '/Users/ghaith/desktop/test_project_1',
#  'Config_file_path': '/Users/ghaith/desktop/test_project_1/test_project_1.project.yaml',
#  'data_path': {'ultralytics_data_path': None, 'Biigle_path': None},
#  'models': [{'model_path': 'yolov8n.pt', 'model_name': 'best model'}],
#  'tracking': {'Mlflow': {'path': None,
#                          'experiment_name': None,
#                          'mlflow.db': '/Users/ghaith/desktop/test_project_1/mlflow.db'}},
#  'metadata': None}

# %% [markdown]
# ## Add a dataset to the project.

# %%
# Calling add_data without the argument "data_path" adds the default COCO8 dataset for demonstration.
# This prepares the data configuration required for training.
add_data(
    project=project,
    data_type="Biigle_dataset",
    data_path="~/desktop/output/biigle_dataset/27737-baltic.csv",
    IMAGES_ROOT="~/desktop/output/biigle_dataset/baltic_images",
    DATASET_DIR="~/desktop/test_project_1",
)
# Out:
# 08-Feb-26 00:46:14 - INFO - data was retreived successfully
# Loaded 169 annotations from CSV
# Supported annotations (Rectangle/Polygon): 169
#
# Detected 4 classes:
#   0: Gobiidae (40 annotations)
#   1: Perca fluviatilis (2 annotations)
#   2: Saduria entomon (125 annotations)
#   3: Zoarces viviparus (2 annotations)
#
# Converted 169 annotations to YOLO format
# [split] Images: 89 | train=62 val=18 test=9
# Dataset created
#   train: 62 images, 119 annotations
#   valid: 18 images, 34 annotations
#   test: 9 images, 16 annotations
# Created 31 augmented images
#   Train set: 62 -> 93 images
# Wrote /Users/ghaith/desktop/test_project_1/data.yaml
# 08-Feb-26 00:46:15 - INFO - data was dumped successfully
# 08-Feb-26 00:46:15 - INFO - Project YAML data path updated at /Users/ghaith/desktop/test_project_1/test_project_1.project.yaml
# {'Project_name': 'test_project_1',
#  'Project_path': '/Users/ghaith/desktop/test_project_1',
#  'Config_file_path': '/Users/ghaith/desktop/test_project_1/test_project_1.project.yaml',
#  'data_path': {'ultralytics_data_path': None,
#                'Biigle_path': '/Users/ghaith/desktop/test_project_1/data.yaml'},
#  'models': [{'model_path': 'yolov8n.pt', 'model_name': 'best model'}],
#  'tracking': {'Mlflow': {'path': None,
#                          'experiment_name': None,
#                          'mlflow.db': '/Users/ghaith/desktop/test_project_1/mlflow.db'}},
#  'metadata': None}

# %% [markdown]
# ## OPTIONAL DATA AUGMENTATION

# %%
# Controls whether and how dataset augmentation is applied.

# - data_type: selects which dataset to augment
#   ("Biigle_path" or "ultralytics_data_path")
# - AUGMENT_FACTOR: fraction of the dataset to augment (0–1)
# - RANDOM_SEED: ensures reproducibility
data_type = "Biigle_path"  # or "ultralytics_data_path"
augment_factor = 0.5
random_seed = 42

run_augmentation(
    project=project,
    data_type=data_type,
    augment_factor=augment_factor,
    random_seed=random_seed,
)
