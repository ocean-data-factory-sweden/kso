# %% [markdown]
# ## Model inference

# %%
import os
from kso2 import (
    loading_model,
    model_inference,
    save_predictions,
)
# Out:
# 29-Jan-26 14:11:04 - INFO - Using default logging config without output log file
# /Users/ghaith/Desktop/kso/kso/.venv/lib/python3.12/site-packages/mlflow/pyfunc/utils/data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(

# %%
project = load_project("Test project 1")

# %%
model = loading_model(model_name="test model", version=1)
# Out:
# models:/test model/1
# 2026/01/29 14:11:04 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/29 14:11:04 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/29 14:11:04 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/29 14:11:04 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/29 14:11:04 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# ...

# %%
import cv2

image = "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000036.jpg"
img = cv2.imread(image)
img = cv2.resize(img, (640, 640))
dir = "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val"

# %%
result = model_inference(model=model, data_path=dir)
# Out:
# 29-Jan-26 14:11:09 - INFO - [{'boxes': [[173.39244079589844, 158.66693115234375, 466.9332275390625, 639.3404541015625], [2.61541748046875, 57.10279846191406, 463.4969787597656, 479.4588623046875]], 'plot': array([[[172, 167,  98],
#         [175, 170, 101],
#         [178, 173, 104],
#         ...,
#         [ 78,  81,  65],
#         [ 78,  82,  63],
#         [ 89,  95,  72]],
#
#        [[179, 174, 105],
#         [179, 174, 105],
#         [179, 174, 105],
#         ...,
#         [ 59,  61,  42],
#         [ 55,  60,  39],
#         [ 42,  46,  21]],
#
#        [[184, 182, 112],
#         [179, 177, 107],
#         [174, 172, 102],
#         ...,
#         [ 83,  85,  63],
#         [ 80,  84,  59],
#         [ 87,  90,  64]],
#
#        ...,
#
#        [[124, 112,  48],
#         [121, 109,  45],
#         [126, 114,  50],
#         ...,
#         [104, 101,  46],
#         [105,  99,  40],
#         [116, 103,  41]],
#
#        [[129, 117,  53],
#         [127, 115,  51],
# ...

# %%
save_predictions(
    project=project,
    predictions=result,
    save_dir="/Users/ghaith/Desktop/kso/kso/projects/test_project_1/f",
)
# Out:
# 29-Jan-26 14:11:25 - INFO - Saving inference results to: /Users/ghaith/Desktop/kso/kso/projects/test_project_1/f/inference_results

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(
    "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/yolov8n.pt"
)  # pretrained YOLO26n model
img1 = "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000036.jpg"
img2 = (
    "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/yebra.jpeg"
)
dir = "/Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val"
# Run batched inference on a list of images
results = model(
    dir, save_dir="/Users/ghaith/Desktop/kso/kso/projects/test_project_1/runs/detect"
)
# Out:
# image 1/4 /Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000036.jpg: 640x512 1 person, 1 umbrella, 54.6ms
# image 2/4 /Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000042.jpg: 480x640 1 dog, 1 suitcase, 50.4ms
# image 3/4 /Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000049.jpg: 640x512 4 persons, 1 dog, 2 horses, 1 potted plant, 54.6ms
# image 4/4 /Users/ghaith/Desktop/kso/kso/projects/test_project_1/coco8/images/val/000000000061.jpg: 512x640 1 person, 1 elephant, 52.3ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)

# %% [markdown]
# ## Tracking

# %% [markdown]
# ## Analytics
