# %%
import sys
from pathlib import Path

sys.path.append(str(Path("/Users/ghaith/Desktop/kso/kso/kso2/src").resolve()))

# %%
import os
from dataclasses import dataclass
from kso2_utils import create_project, setup_data, setup_model, training_model,load_project

# %%
create_project("Test Project")
# Out:
# {'Project_name': 'Test Project', 'Project_path': '/Users/ghaith/Desktop/kso/kso/kso2/projects/test_project', 'Data': {'path': 'None'}, 'model': {'weights_path': None, 'model_name': None}, 'tracking': None, 'metadata': None}
# PosixPath('/Users/ghaith/Desktop/kso/kso/kso2/projects/test_project/test_project.project.yaml')

# %%
setup_data(project_path="test_project",data="~/Desktop/kso/kso/kso2/projects/coco8.yaml")
# Out:
# PosixPath('/Users/ghaith/Desktop/kso/kso/kso2/projects/test_project/test_project.project.yaml')

# %%
setup_model(project_path="test_project",model_name="yolov8n.pt",weights_path="~/Desktop/yolov8n.pt")
# Out:
# PosixPath('/Users/ghaith/Desktop/kso/kso/kso2/projects/test_project/test_project.project.yaml')

# %%
project=load_project(project_name="test_project")

# %%
project.weights_path
# Out:
# '/Users/ghaith/Desktop/yolov8n.pt'

# %%
project.data
# Out:
# '/Users/ghaith/Desktop/kso/kso/kso2/projects/coco8.yaml'

# %%
from ultralytics import YOLO

# %%
YOLO??
# Out:
# Init signature:
# YOLO(
#     model: Union[str, pathlib.Path] = 'yolo11n.pt',
#     task: Optional[str] = None,
#     verbose: bool = False,
# )
# Source:
# class YOLO(Model):
#     """
#     YOLO (You Only Look Once) object detection model.
#
#     This class provides a unified interface for YOLO models, automatically switching to specialized model types
#     (YOLOWorld or YOLOE) based on the model filename. It supports various computer vision tasks including object
#     detection, segmentation, classification, pose estimation, and oriented bounding box detection.
#
#     Attributes:
#         model: The loaded YOLO model instance.
#         task: The task type (detect, segment, classify, pose, obb).
#         overrides: Configuration overrides for the model.
#
#     Methods:
#         __init__: Initialize a YOLO model with automatic type detection.
#         task_map: Map tasks to their corresponding model, trainer, validator, and predictor classes.
#
#     Examples:
# ...

# %%
model = YOLO(project.weights_path)

# %%
model.info()
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %%
training_model("test_project")
# Out:
# New https://pypi.org/project/ultralytics/8.3.231 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.166 🚀 Python-3.10.19 torch-2.9.0 CPU (Apple M1)
# ...
